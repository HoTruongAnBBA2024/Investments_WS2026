# %% [markdown]
# ### 📌 BỨC TRANH TỔNG QUAN: ĐỊNH GIÁ TRÁI PHIẾU & CẤU TRÚC KỲ HẠN LÃI SUẤT
# *(Bond Valuation & Term Structure of Interest Rates)*
#
# Chào mừng bạn đến với chương học cốt lõi của môn **Investment Finance**. Trước khi đi sâu vào các công thức phức tạp, hãy cùng nhau nhìn nhận toàn bộ bài học này dưới một lăng kính thực tế và gần gũi nhất.
#
# ---
#
# ### 1. Nội dung chính của bài học là gì?
# Bài học này xoay quanh **hai mảng lớn** liên quan chặt chẽ đến nhau:
# 1. **Định giá Trái phiếu (Bond Valuation):** Tìm hiểu trái phiếu là gì, các đặc tính của nó (mệnh giá, lãi suất coupon, điều khoản mua lại) và cách xác định giá trị hợp lý của một trái phiếu trên thị trường dựa trên dòng tiền tương lai.
# 2. **Cấu trúc kỳ hạn của lãi suất (Term Structure of Interest Rates):** Giải thích lý do vì sao cùng một tổ chức phát hành (ví dụ: Chính phủ), nhưng các khoản vay có kỳ hạn khác nhau (1 năm, 5 năm, 30 năm) lại có mức lãi suất khác nhau. Đây chính là khái niệm về **Đường cong lãi suất (Yield Curve)**.
#
# ---
#
# ### 2. Mục tiêu cốt lõi bạn cần đạt được
# Sau bài này, bạn cần tự tin trả lời và tính toán được các tiêu chí sau:
# * 🎯 **Định giá được trái phiếu:** Biết cách áp dụng công thức chiết khấu dòng tiền để tính giá trị hiện tại ($P_B$) của trái phiếu.
# * 🎯 **Phân biệt các loại lợi suất:** Hiểu và tính toán được **Yield to Maturity (YTM)**, **Yield to Call (YTC)**, và **Realized Compound Return** (Lợi suất thực tế nhận được khi có tính đến yếu tố tái đầu tư).
# * 🎯 **Hiểu về rủi ro thu hồi (Callable Bonds):** Biết khi nào doanh nghiệp sẽ mua lại trái phiếu trước hạn và ảnh hưởng của nó đến nhà đầu tư.
# * 🎯 **Giải mã Đường cong lãi suất:** Hiểu được cách tính **Lãi suất kỳ hạn (Forward Rate)** từ **Lãi suất giao ngay (Spot Rate)** và nắm giữ 2 lý thuyết giải thích hình dạng đường cong này (*Expectations Hypothesis* & *Liquidity Preference Theory*).
#
# ---
#
# ### 3. Tại sao kiến thức này cực kỳ quan trọng với một sinh viên BBA?
# Là một sinh viên Quản trị Kinh doanh (BBA), dù bạn chọn chuyên ngành Tài chính, Khởi nghiệp hay Quản trị, bài học này mang lại những lợi ích thực tế rất lớn:
# * 💼 **Quản trị rủi ro & Huy động vốn doanh nghiệp:** Nếu sau này bạn làm quản lý tài chính cho doanh nghiệp (CFO), bạn cần biết khi nào nên phát hành trái phiếu để gọi vốn, và khi nào nên mua lại trước hạn (Call) để tiết kiệm chi phí lãi vay khi thị trường giảm lãi suất.
# * 📈 **Tư duy đầu tư cá nhân & tổ chức:** Hiểu được mối quan hệ ngược chiều giữa **Giá trái phiếu** và **Lãi suất thị trường** (Lãi suất tăng $\rightarrow$ Giá trái phiếu giảm và ngược lại). Đây là nền tảng tối thiểu để bạn quản lý danh mục đầu tư cá nhân hoặc tư vấn đầu tư.
# * 🌐 **Đọc vị nền kinh tế vĩ mô:** Đường cong lãi suất được coi là "hệ thống cảnh báo sớm" của nền kinh tế. Hiểu được nó sẽ giúp bạn dự đoán các chu kỳ suy thoái hoặc lạm phát để đưa ra các quyết định kinh doanh nhạy bén.
#
# ---
#
# ### 4. Ví dụ thực tế hàng ngày giúp bạn dễ hình dung
#
# #### 💡 Ví dụ 1: Chuyện cho bạn vay tiền (Khái niệm Coupon và Par Value)
# Bạn cho một người bạn vay **10 triệu đồng** (Mệnh giá - Par value) trong **3 năm**. Người bạn này hứa mỗi năm sẽ trả bạn **1 triệu đồng** tiền cà phê/cảm ơn (Lãi coupon - 10%/năm), và đến cuối năm thứ 3 sẽ trả lại đúng **10 triệu đồng** tiền gốc.
# * *Giá trị trái phiếu thay đổi:* Nếu sau 1 năm, ngân hàng đột ngột tăng lãi suất tiền gửi lên rất cao (ví dụ 15%), việc bạn giữ cam kết cho vay 10% kia bỗng trở nên kém hấp dẫn. Nếu bạn muốn bán lại "quyền đòi nợ" này cho người khác, bạn buộc phải giảm giá bán xuống dưới 10 triệu thì mới có người chịu mua (Trái phiếu giao dịch dưới mệnh giá - *Discount bond*).
#
# #### 💡 Ví dụ 2: Kỳ hạn gửi tiết kiệm (Khái niệm Term Structure)
# Khi bạn ra ngân hàng gửi tiết kiệm:
# * Gửi kỳ hạn **1 tháng** lãi suất chỉ là **3%/năm**.
# * Gửi kỳ hạn **12 tháng** lãi suất là **5.5%/năm**.
# Tại sao kỳ hạn dài hơn thường có lãi suất cao hơn?
# 1. Vì bạn chịu rủi ro bị chôn vốn lâu hơn mà không biết tương lai có lạm phát hay không (Đòi hỏi bù đắp rủi ro - *Liquidity Premium*).
# 2. Vì mọi người kỳ vọng nền kinh tế sắp tới sẽ ấm lên và lãi suất chung sẽ tăng (*Expectations Hypothesis*).

# %% [markdown]
# <center>
# <img src="https://github.com/HoTruongAnBBA2024/Investments_WS2026/blob/main/images/fscampus_small2.png?raw=1" width="1200"/>
# </center>
#
# <center>
#
# # Investments
#
# ***Finance 2 - BFIN***
#
# **Dr. Omer Cayirli**
#
# Lecturer in Empirical Finance
#
# omer_cayirli@uncbusiness.net
# </center>
#
#
# ---

# %% [markdown]
# ## Lecture 02
# ---

# %% [markdown]
# ### Outline
#
# *   Fixed-Income Securities I
#
#     *   Bond Prices and Yields
#
#     *   The Term Structure of Interest Rates
#
# ---

# %% [markdown]
# ### Bond Prices and Yields
#
# * Bond Characteristics
#
#     - A security that is issued in connection with a borrowing arrangement.
#
#     - Par value or face value
#
#     - Coupon payments
#
#     - Coupon rate
#
#     - Bond indenture
#       - The contract between the issuer and the bondholder
#
# ---

# %% [markdown]
# #### Government Bonds and Notes
# *   Bonds and notes may be purchased directly from the Treasury
#     *   Note maturity: 1-10 years
#     *   Bond maturity: 10-30 years
#
# #### Corporate Bonds
# *   Callable bonds
#     *   Can be repurchased before the maturity date
#         *   Call price
#         *   Call protection, deferred callable bonds.
# *   Puttable Bonds
#     *   Give the holder an option to retire or extend the bond
# *   Convertible bonds
#     *   Can be exchanged for shares of the firm's common stock
#     *   Conversion ratio: The number of shares for which each bond may be exchanged.
#         *   Market conversion value
#         *   Conversion premium
# *   Floating-rate bonds
#     *   The coupon rate adjusts to changes in a reference rate (e.g., policy/market rate), not to the issuer’s credit condition.
#
# ---

# %% [markdown]
# ### 📖 BÀI GIẢNG CHI TIẾT: CHỨNG KHOÁN CHÍNH PHỦ & TRÁI PHIẾU DOANH NGHIỆP
# *(Government Bonds/Notes vs. Corporate Bonds)*
#
# Dựa trên nội dung slide tiếp theo, chúng ta sẽ cùng phân tích hai nhóm công cụ nợ phổ biến nhất trên thị trường tài chính: **Trái phiếu Chính phủ** (rủi ro cực thấp) và **Trái phiếu Doanh nghiệp** (nhiều điều khoản phức tạp).
#
# ---
#
# ### I. Trái phiếu Chính phủ (Government Bonds & Notes)
# Đây là các công cụ nợ do Bộ Tài chính Mỹ (hoặc Chính phủ các nước) phát hành nhằm bù đắp thâm hụt ngân sách hoặc tài trợ cho các công trình công cộng. Chúng được coi là **không có rủi ro vỡ nợ (risk-free)** vì Chính phủ có quyền in tiền hoặc thu thuế để trả nợ.
#
# *   **Maturity (Kỳ hạn):**
#     *   **Treasury Notes (Kỳ phiếu):** Kỳ hạn từ **1 đến 10 năm**.
#     *   **Treasury Bonds (Trái phiếu):** Kỳ hạn dài hơn, từ **10 đến 30 năm**.
# *   *Lưu ý thực tế:* Cả hai loại này đều trả lãi định kỳ (thường là 6 tháng một lần) và hoàn trả mệnh giá khi đáo hạn.
#
# ---
#
# ### II. Trái phiếu Doanh nghiệp (Corporate Bonds)
# Khác với Chính phủ, doanh nghiệp phát hành trái phiếu luôn đi kèm với **rủi ro tín dụng (credit risk)**. Để thu hút nhà đầu tư hoặc để bảo vệ bản thân khi lãi suất thị trường biến động, doanh nghiệp thường thiết kế thêm các **điều khoản đi kèm (embedded options)**. Dưới đây là các loại phổ biến nhất:
#
# #### 1. Trái phiếu có điều khoản thu hồi (Callable Bonds)
# *   **Là gì?** Doanh nghiệp phát hành có quyền mua lại (thu hồi) trái phiếu từ tay nhà đầu tư trước khi đáo hạn với một mức giá ấn định trước gọi là **Call Price**.
# *   **Tại sao doanh nghiệp lại làm vậy?** Hãy tưởng tượng doanh nghiệp phát hành trái phiếu với lãi suất **10%/năm**. Sau 2 năm, lãi suất thị trường giảm sâu xuống còn **5%/năm**. Lúc này, doanh nghiệp sẽ "thu hồi" trái phiếu cũ (trả tiền gốc cho bạn) rồi phát hành trái phiếu mới với lãi suất 5% để tiết kiệm chi phí đi vay.
# *   **Rủi ro cho nhà đầu tư:** Bạn bị mất nguồn thu nhập lãi suất cao (10%) và phải mang tiền đi tái đầu tư với lãi suất thấp hơn (Reinvestment risk). Do đó, loại trái phiếu này thường có **Call Protection** (giai đoạn cam kết không được thu hồi trước hạn).
#
# #### 2. Trái phiếu có quyền bán lại (Puttable Bonds)
# *   Ngược lại với Callable Bond, loại này cho phép **nhà đầu tư** có quyền bắt doanh nghiệp phải mua lại trái phiếu trước hạn.
# *   **Khi nào bạn dùng quyền này?** Khi lãi suất thị trường tăng lên mạnh mẽ, bạn muốn rút tiền sớm để mang đi gửi nơi khác có lãi suất cao hơn.
#
# #### 3. Trái phiếu chuyển đổi (Convertible Bonds)
# *   Cho phép bạn chuyển đổi trái phiếu thành một số lượng **cổ phiếu phổ thông** nhất định của chính doanh nghiệp đó theo một tỷ lệ quy định trước (**Conversion Ratio**).
# *   Loại này rất được ưa chuộng vì nó vừa an toàn (nhận lãi cố định như trái phiếu) vừa có cơ hội tăng trưởng tài sản (nếu giá cổ phiếu của doanh nghiệp tăng mạnh).
#
# #### 4. Trái phiếu lãi suất thả nổi (Floating-rate Bonds)
# *   Lãi suất coupon không cố định mà tự động điều chỉnh theo một lãi suất tham chiếu trên thị trường (ví dụ: lãi suất liên ngân hàng SOFR hoặc lãi suất chính sách của Ngân hàng Trung ương).
#
# ---
#
# ### 🧠 CÂU HỎI SUY NGẪM CHO SINH VIÊN BBA:
#
# Giả sử bạn là một nhà đầu tư đang tìm kiếm lợi nhuận ổn định. Giữa hai trái phiếu có các đặc tính hoàn toàn giống nhau về kỳ hạn và uy tín của tổ chức phát hành:
# 1.  **Trái phiếu A:** Có điều khoản thu hồi (Callable Bond).
# 2.  **Trái phiếu B:** Trái phiếu thông thường không có điều khoản thu hồi (Straight Bond).
#
# *Theo bạn, trái phiếu nào sẽ yêu cầu mức lãi suất coupon ban đầu **cao hơn** để hấp dẫn bạn mua? Tại sao lại như vậy? (Hãy liên hệ trực tiếp đến rủi ro mà bạn phải gánh chịu).*
#
# *Hãy thử trả lời câu hỏi này dưới góc nhìn của một nhà quản trị tài chính nhé!*

# %% [markdown]
# #### Preferred Stock
# *   Specifies a dividend rate, which may be fixed or floating.
#
# *   Payment of dividends is not guaranteed.
#
# *   Dividends are not tax-deductible for the issuer.
#
# | Like Fixed Income | Like Equity |
# | :--- | :--- |
# | Dividend rates are typically fixed. | Often has no fixed maturity date; may be callable. |
# | Preferred dividends have priority over common dividends. | Omitting a dividend does not by itself trigger bankruptcy. |
#
# ---

# %% [markdown]
# #### Other Domestic Issuers
# *   Local governments
#
# *   Government agencies
#
# #### International Bonds
#
# *   Foreign Bonds
#     *   Borrower is from a country other than the one in which the bond is sold.
#     *   The bond is denominated in the currency of the country in which it is marketed.
#         *   Yankee Bonds
#         *   Samurai Bonds
#         *   Bulldog Bonds
#
# *   Eurobonds
#     *   Denominated in one currency, usually that of the issuer, but sold in other national markets.
#         *   Eurodollar
#         *   Euroyen
#         *   Eurosterling
#
# ---

# %% [markdown]
# #### Inverse Floaters
# *   Similar to the floating-rate bonds.
# *   The coupon rate on these bonds falls when the general level of interest rates or reference rate rises.
#
# #### Asset-Backed Bonds
# *   The income from a specified group of assets is used to service the debt.
#
# #### Catastrophe Bonds
# *   A way to transfer "catastrophe risk" to the capital markets.
#     *   Higher coupon rates
#     *   In the event of a catastrophe, the bondholders lose all or part of their investments.
#     *   [World Bank "pandemic bonds”](https://www.worldbank.org/en/topic/pandemics/brief/fact-sheet-pandemic-emergency-financing-facility)
#         *   Issued in 2018, during COVID-19 $195 million paid to 64 developing countries.
#
# ---

# %% [markdown]
# ### Bond Prices and Yields
#
# #### Indexed Bonds
# *   Payments are tied to a reference
#     *   Price index
#     *   Commodity prices
#     *   GDP
# *   Treasury Inflation Protected Securities (TIPS)
#     *   In a simplified example, Delta buys a 3-year inflation-indexed bond with an initial par value of \$1,000 and a 3% coupon rate. Assume annual coupons on the inflation-adjusted principal and inflation of 3%, 2%, and 4% in the next three years.
#
# | Time | Inflation in Year Just Ended | Par Value | Coupon Payment | Principal Repayment | Total Payment |
# | :---: | :---------------------------: | :--------: | :-------------: | :------------------: | ------------: |
# | 0 | | 1,000.00 | | | |
# | 1 | 3% | 1,030.00 | 30.90 | 0.00 | 30.90 |
# | 2 | 2% | 1,050.60 | 31.52 | 0.00 | 31.52 |
# | 3 | 4% | 1,092.62 | 32.78 | 1,092.62 | 1,125.40 |
#
#
# ---

# %% [markdown]
# ### Bond Prices and Yields
# *   The nominal risk-free interest rate is approximately the sum of
#     *   A real risk-free rate of return.
#     *   Compensation for expected inflation.
# *   A bond's required yield also reflects its default risk, liquidity, tax treatment, and call risk.
#
# $$ P_B = \sum_{t=1}^{T} \frac{C}{(1+r)^t} + \frac{Par Value}{(1+r)^T} $$
#
# $$ P_B = C * \frac{1}{r} \left[1 - \frac{1}{(1+r)^T}\right] + \frac{Par Value}{(1+r)^T} $$
#
# *   Theta issues a 10-year bond with a par value of \$1,000 and a 6% annual coupon rate, paid semiannually. If its yield to maturity is 8% per year, compounded semiannually, what is the bond's price?
#
# $$ P_B = \frac{1,000 \cdot 6\%}{2} \cdot \frac{1}{8\%/2} \left[1 - \frac{1}{(1+8\%/2)^{20}}\right] + \frac{1,000}{(1+8\%/2)^{20}} $$
#
# $$P_B = \$864.10$$
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

# --- 1. Core Calculation Function ---
def calculate_bond_price(face_value, coupon_rate, market_rate, years_to_maturity, freq=1):
    """
    Calculates the price of a bond.

    Args:
        face_value (float): The par value of the bond.
        coupon_rate (float): The annual coupon rate (in decimal form, e.g., 0.08 for 8%).
        market_rate (float): Nominal annual YTM, compounded at the coupon frequency (in decimal form).
        years_to_maturity (int): The number of years until the bond matures.
        freq (int): Number of coupon payments per year.
    """
    # Adjust rates and periods for payment frequency
    periods = years_to_maturity * freq
    coupon_payment = (face_value * coupon_rate) / freq
    r = market_rate / freq

    # Handle edge case for zero market rate
    if r == 0:
        pv_coupons = coupon_payment * periods
    else:
        pv_coupons = coupon_payment * ((1 - (1 + r)**-periods) / r)

    pv_face_value = face_value / (1 + r)**periods

    return pv_coupons + pv_face_value

# --- 2. Plotting Function ---
def generate_bond_plot(coupon_rate, years_to_maturity, current_market_rate, coupon_frequency=1):
    """
    Generates and displays the bond price vs. interest rate plot.
    """
    # Convert slider percentages to decimals for calculation
    coupon_r = coupon_rate / 100
    market_r = current_market_rate / 100
    face_value = 1000

    # --- Data for the curve ---
    # Create a range of interest rates for the x-axis
    rates_range = np.linspace(0.001, 0.20, 200) # From 0.1% to 20%
    # Calculate bond price for each interest rate in the range
    prices = [calculate_bond_price(face_value, coupon_r, r, years_to_maturity, freq=coupon_frequency) for r in rates_range]

    # --- Calculate the price for the single interactive point ---
    current_price = calculate_bond_price(face_value, coupon_r, market_r, years_to_maturity, freq=coupon_frequency)

    # --- Plotting ---
    fig, ax = plt.subplots(figsize=(8, 5))

    # Plot the main curve
    ax.plot(rates_range * 100, prices, color='deepskyblue', linewidth=2.5)

    # Plot the interactive point
    ax.plot(current_market_rate, current_price, 'o', color='red', markersize=8, zorder=5)

    # Plot the dashed lines to the axes
    ax.plot([current_market_rate, current_market_rate], [0, current_price], 'r--', alpha=0.7)
    ax.plot([0, current_market_rate], [current_price, current_price], 'r--', alpha=0.7)

    # Add text annotation for the point
    ax.text(current_market_rate + 0.5, current_price + 50,
            f'({current_market_rate:.1f}%, ${current_price:,.2f})',
            fontsize=12, color='black')

    # --- Formatting ---
    frequency_label = {1: 'annual', 2: 'semiannual', 4: 'quarterly'}[coupon_frequency]
    ax.set_title(f'Bond Price vs. Market Rate\n{coupon_rate:g}% coupon, {years_to_maturity} years, {frequency_label} payments', fontsize=16)
    ax.set_xlabel('Nominal Annual Interest Rate (%)', fontsize=12)
    ax.set_ylabel('Bond Price ($)', fontsize=12)
    ax.set_xlim(0, 20)
    ax.set_ylim(bottom=0, top=max(prices) * 1.1) # Dynamic top limit
    ax.grid(True, linestyle='--', alpha=0.6)

    plt.show()

# --- 3. Interactive Widgets Setup ---

# Define the widgets for user input
coupon_rate_widget = widgets.FloatSlider(
    value=5.0, min=0, max=20, step=0.5,
    description='Coupon Rate (%):', style={'description_width': 'initial'}, continuous_update=False
)
years_widget = widgets.IntSlider(
    value=30, min=1, max=50, step=1,
    description='Years to Maturity:', style={'description_width': 'initial'}, continuous_update=False
)
market_rate_widget = widgets.FloatSlider(
    value=5.0, min=0.1, max=20, step=0.1,
    description='Market Interest Rate (%):', style={'description_width': 'initial'}, continuous_update=True,
)

bond_price_frequency_widget = widgets.Dropdown(
    options=[('Annual', 1), ('Semiannual', 2), ('Quarterly', 4)],
    value=1,
    description='Coupon Frequency:', style={'description_width': 'initial'}
)

# Capture each update in this demonstration's own output widget.
bond_price_output = widgets.interactive_output(
    generate_bond_plot,
    {
        'coupon_rate': coupon_rate_widget,
        'years_to_maturity': years_widget,
        'current_market_rate': market_rate_widget,
        'coupon_frequency': bond_price_frequency_widget
    }
)

# Arrange the widgets in a box
bond_price_controls = widgets.VBox([
    widgets.HTML("<h3>Set Bond Characteristics:</h3>"),
    coupon_rate_widget,
    bond_price_frequency_widget,
    years_widget,
    market_rate_widget
])

# Display the controls and the output area
display(bond_price_controls, bond_price_output)
# Out:
# ...
# Output()

# %% [markdown]
# ### Accrued Interest and Quoted Bond Prices
# *   If a bond is purchased between coupon payments, the buyer must pay the seller for accrued interest.
#     *   It is the prorated share of the upcoming semiannual coupon.
#     *   The quoted price does not include the interest that accrues between coupon payment dates.
#
# $$ \text{Accrued interest} = \frac{\text{Annual coupon payment}}{2} \times \frac{\text{Days since last coupon payment}}{\text{Days separating coupon payments}} $$
#
# *   Gamma buys a bond 45 days after its last coupon payment. The bond has a \$1,000 par value, a 6% annual coupon paid semiannually, and 180 days between coupon payments. How much accrued interest does Gamma pay the seller?
#
# $$ \text{Accrued Interest} = \text{Coupon payment} \times \frac{\text{Days since last coupon payment}}{\text{Days separating coupon payments}} $$
#
# $$ \text{Accrued Interest} = \frac{1,000 \cdot 6\%}{2} \cdot \frac{45}{180} = \$7.50 $$
#
# *   Stocks trade without a separate "accrued dividend" payment. Investors who buy before the ex-dividend date and hold until that date receive the upcoming dividend; buyers on or after that date do not. All else equal, the share price falls by the dividend amount on the ex-dividend date.
#
# ---

# %% [markdown]
# ### Yield to Maturity
# *   The interest rate that makes the present value of a bond's payments equal to its price.
#
# *   A measure of the average rate of return that will be earned on a bond if it is bought now and held until maturity.
#
#     *   Assumption: All coupons can be reinvested at YTM
#
# ### Current yield
# *   The bond's annual coupon payment divided by its price.
#
# *   Lambda buys a 5-year bond for $\$1,085.30$. Its par value is $\$1,000$, and it pays $\$40$ every six months. Find its current yield, nominal annual yield to maturity, and effective annual yield.
#
# $$ \text{Current Yield} = \frac{\text{Annual Coupon}}{\text{Price}} $$
#
# $$ \text{Current Yield} = \frac{40 \cdot 2}{1,085.30} = 7.37\% $$
#
# $$ 1,085.30 \approx 40 \cdot \frac{1}{r/2} \left[1 - \frac{1}{(1+r/2)^{10}}\right] + \frac{1,000}{(1+r/2)^{10}} $$
#
# $$ r/2 \approx 3\% \quad \Rightarrow \quad r \approx 6\% \quad \Rightarrow \quad \text{Effective annual yield} = (1.03)^2 - 1 = 6.09\% $$
#
# ---

# %%
#!pip install ipywidgets matplotlib

import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output

# ----------------------------
# COUPON-DATE BOND VALUES
# ----------------------------
def bond_price(remaining_maturity, coupon_rate, face_value, ytm, coupon_freq):
    """
    Price on a coupon date, excluding the coupon due on that date.
    At maturity, returns the principal to be repaid.
    """
    # Maturities are sampled at coupon dates; round away floating-point noise.
    periods = int(round(remaining_maturity * coupon_freq))
    if periods == 0:
        return face_value  # At maturity

    period_yield = ytm / coupon_freq
    coupon_pmt = (face_value * coupon_rate) / coupon_freq

    # Discount each remaining payment; this also works when YTM is zero.
    discount_factors = (1 + period_yield) ** (-np.arange(1, periods + 1, dtype=float))
    pv_coupons = coupon_pmt * discount_factors.sum()
    pv_face = face_value * discount_factors[-1]

    return pv_coupons + pv_face

def plot_bond_price_dynamics(face_value, ytm_percent, coupon1_percent, coupon2_percent, coupon_freq):
    """
    Plots exact coupon-date prices as maturity approaches, at a constant YTM.
    """
    # Convert percentages to decimals
    ytm = ytm_percent / 100
    coupon1 = coupon1_percent / 100
    coupon2 = coupon2_percent / 100

    # Include every coupon date for the selected payment frequency.
    maturities = np.arange(5 * coupon_freq, -1, -1) / coupon_freq

    # Compute discrete prices for each coupon rate
    bond_prices_1 = [bond_price(t, coupon1, face_value, ytm, coupon_freq) for t in maturities]
    bond_prices_2 = [bond_price(t, coupon2, face_value, ytm, coupon_freq) for t in maturities]

    # Connect the calculated values without interpolating extra prices.
    plt.figure(figsize=(8, 5), dpi=100)
    plt.plot(maturities, bond_prices_1, marker='o', markersize=4,
             label=f'{coupon1_percent:g}% Coupon Bond (YTM {ytm_percent:g}%)')
    plt.plot(maturities, bond_prices_2, marker='o', markersize=4,
             label=f'{coupon2_percent:g}% Coupon Bond (YTM {ytm_percent:g}%)')

    # Flip axis: 5 years on left to 0 years on right
    plt.gca().invert_xaxis()
    plt.title("Bond Prices on Coupon Dates")
    plt.xlabel("Remaining Maturity (Years)")
    plt.ylabel("Bond Price ($)")
    plt.grid(True, alpha=0.3, linestyle=':')
    plt.legend()
    plt.figtext(0.5, 0.02, "Prices exclude the coupon due; the maturity value is principal. Lines connect the points.",
                ha='center', fontsize=9)
    plt.tight_layout(rect=(0, 0.05, 1, 1))
    plt.show()

# -------------------------
# WIDGETS FOR INTERACTIVITY
# -------------------------
face_value_widget = widgets.FloatText(
    value=1000,
    description='Face Value:'
)
ytm_widget = widgets.FloatText(
    value=10.0,
    description='YTM (%):'
)
coupon1_widget = widgets.FloatText(
    value=8.0,
    description='Coupon1 (%):'
)
coupon2_widget = widgets.FloatText(
    value=12.0,
    description='Coupon2 (%):'
)
# Semiannual, quarterly, or monthly coupon payments.
coupon_freq_widget = widgets.Dropdown(
    options=[2, 4, 12],
    value=2,
    description='Payments/year:'
)

output = widgets.Output()

def on_recalculate_clicked(_):
    with output:
        clear_output()
        plot_bond_price_dynamics(
            face_value_widget.value,
            ytm_widget.value,
            coupon1_widget.value,
            coupon2_widget.value,
            coupon_freq_widget.value
        )

recalculate_button = widgets.Button(description="Recalculate Graph")
recalculate_button.on_click(on_recalculate_clicked)

# Display widgets and button, then immediately generate the graph with default values.
display(
    face_value_widget,
    ytm_widget,
    coupon1_widget,
    coupon2_widget,
    coupon_freq_widget,
    recalculate_button,
    output
)

# Generate the default graph upon first execution.
on_recalculate_clicked(None)
# Out:
# FloatText(value=1000.0, description='Face Value:')
# FloatText(value=10.0, description='YTM (%):')
# FloatText(value=8.0, description='Coupon1 (%):')
# FloatText(value=12.0, description='Coupon2 (%):')
# Dropdown(description='Payments/year:', options=(2, 4, 12), value=2)
# Button(description='Recalculate Graph', style=ButtonStyle())
# Output()

# %% [markdown]
# ### Yield to Call
# <center>
# <img src="https://github.com/HoTruongAnBBA2024/Investments_WS2026/blob/main/images/slide_2/pic_2.png?raw=1" width="720">
# </center>
#
# ---

# %% [markdown]
# ### Yield to Call
#
# *   If the bond is callable, it may be retired prior to the maturity date.
#     *   At higher interest rates, the risk of call is negligible.
#     *   At lower rates, the values of a callable and straight bond begin to diverge.
#     *   The yield to call is calculated just like the yield to maturity
#         *   The time until call replaces time until maturity,
#         *   The call price replaces par value.
#
#
# *   Sigma buys a 20-year bond for $\$1,120$. It has a $\$1,000$ par value and pays $\$40$ every six months. The bond can first be called in five years for $\$1,050$. Find its nominal annual yield to maturity and yield to first call.
#
# $$ 1,120 = 40 \cdot \frac{1}{r/2} \left[1 - \frac{1}{(1+r/2)^{40}}\right] + \frac{1,000}{(1+r/2)^{40}} \quad \Rightarrow \quad r = \text{YTM} \approx 6.89\% $$
#
# $$ 1,120 = 40 \cdot \frac{1}{r/2} \left[1 - \frac{1}{(1+r/2)^{10}}\right] + \frac{1,050}{(1+r/2)^{10}} \quad \Rightarrow \quad r = \text{Yield to first call} \approx 6.05\% $$
#
# ---

# %% [markdown]
# ### Bond Prices and Yields
#
# Alpha and Beta are six-year bonds with \$1,000 par values and semiannual coupons.
# - Alpha's annual coupon rate is 5%; Beta's is 7%.
# - The annual market discount rate is 7%, with semiannual compounding.
# - Both bonds can be called immediately for \$1,040. Assume each is called if its straight-bond value exceeds the call price.
# - If the market discount rate suddenly falls to 5%, what is the capital gain on each bond? Assume no time passes or coupon is paid during the rate change.
#
#
# ---

# %% [markdown]
# ### Bond Prices and Yields
#
# Alpha pays $\$25$ and Beta pays $\$35$ every six months. Each has 12 semiannual periods remaining. The periodic discount rate falls from 3.5% to 2.5%.
#
# $$
# P_{\alpha,0} = 25 \cdot \frac{1-(1.035)^{-12}}{0.035} + \frac{1,000}{(1.035)^{12}} = \$903.37
# $$
#
# Beta's coupon rate matches the initial market rate, so it trades at par.
# $$
# P_{\beta,0} = \$1,000.00
# $$
#
# After the market rate falls to 5%, apply the $\$1,040$ call-price cap to each straight-bond value.
#
# $$
# P_{\alpha,1} = \min\left(25 \cdot \frac{1-(1.025)^{-12}}{0.025} + \frac{1,000}{(1.025)^{12}},\ 1{,}040\right)
# $$
#
# $$
# P_{\alpha,1} = \min\left(1{,}000.00,\ 1{,}040.00\right) = \$1,000.00
# $$
#
# $$
# P_{\beta,1} = \min\left(35 \cdot \frac{1-(1.025)^{-12}}{0.025} + \frac{1,000}{(1.025)^{12}},\ 1{,}040\right)
# $$
#
# $$
# P_{\beta,1} = \min\left(1{,}102.58,\ 1{,}040.00\right) = \$1,040.00
# $$
#
# $$
# \text{Capital gain (Alpha)} = \$1,000.00 - \$903.37 = \$96.63
# $$
#
# $$
# \text{Capital gain (Beta)} = \$1,040.00 - \$1,000.00 = \$40.00
# $$
#
# ---

# %% [markdown]
# #### Realized Compound Return versus Yield to Maturity
# *   Yield to maturity will equal the rate of return realized over the life of the bond if all coupons are reinvested to earn the bond's yield to maturity.
#
# <center>
# <img src = "../images/slide_2/pic_3.png" width="960">
# </center>
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, HTML

# --- 1. Core Calculation Functions ---

def calculate_reinvestment_bond_price(face_value, coupon_rate, ytm, years, freq=1):
    periods = years * freq
    coupon_payment = (face_value * coupon_rate) / freq
    r = ytm / freq
    if r == 0:
        pv_coupons = coupon_payment * periods
    else:
        pv_coupons = coupon_payment * ((1 - (1 + r)**-periods) / r)
    pv_face_value = face_value / (1 + r)**periods
    return pv_coupons + pv_face_value

def calculate_realized_return(price, coupon_rate, years, reinvestment_rate):
    face_value = 1000.0
    coupon_payment = face_value * coupon_rate
    n_periods = years
    r = reinvestment_rate
    if r == 0:
        fv_of_all_coupons = coupon_payment * n_periods
    else:
        fv_of_all_coupons = coupon_payment * (((1 + r)**n_periods - 1) / r)
    total_future_value = fv_of_all_coupons + face_value
    if price > 0:
        realized_return = (total_future_value / price)**(1 / years) - 1
    else:
        realized_return = 0
    return total_future_value, realized_return

# --- 2. Plotting and Display Function ---

def generate_output(coupon, maturity, ytm, current_reinvest_rate):
    coupon_r = coupon / 100
    ytm_r = ytm / 100
    reinvest_r = current_reinvest_rate / 100

    initial_price = calculate_reinvestment_bond_price(1000.0, coupon_r, ytm_r, maturity)
    reinvest_rates_range = np.linspace(0, 0.15, 151)
    realized_returns_curve = [calculate_realized_return(initial_price, coupon_r, maturity, r)[1] for r in reinvest_rates_range]

    fv_at_point, realized_r_at_point = calculate_realized_return(initial_price, coupon_r, maturity, reinvest_r)

    color = "green" if np.isclose(realized_r_at_point, ytm_r, atol=1e-4) else ("red" if realized_r_at_point < ytm_r else "blue")
    summary_html = f"""
    <div style="font-family: Arial, sans-serif; font-size: 1.1em; line-height: 1.6;">
        <b>Initial Bond Purchase Price (V₀):</b> ${initial_price:,.2f}<br>
        <b>Promised Yield to Maturity (YTM):</b> {ytm:.2f}%<br>
        <hr>
        <b>Total Future Value at Maturity (Vₜ):</b> ${fv_at_point:,.2f} (at current reinvestment rate)<br>
        <hr>
        <b style="font-size: 1.2em;">Realized Compound Return: <span style="color:{color};">{realized_r_at_point*100:.2f}%</span></b>
    </div>
    """
    display(HTML(summary_html))

    fig, ax = plt.subplots(figsize=(10, 6))

    ax.plot(reinvest_rates_range * 100, np.array(realized_returns_curve) * 100, color='dodgerblue', linewidth=2.5, label='Realized Return')
    ax.axhline(y=ytm, color='grey', linestyle='--', label=f'Promised YTM ({ytm:.1f}%)')
    ax.plot(current_reinvest_rate, realized_r_at_point * 100, 'o', color='red', markersize=10, zorder=10)
    ax.text(current_reinvest_rate + 0.3, realized_r_at_point * 100,
            f'({current_reinvest_rate:.1f}%, {realized_r_at_point*100:.2f}%)',
            fontsize=11, verticalalignment='bottom')

    ax.set_title(f'Realized Return vs. Reinvestment Rate ({coupon}% Coupon, {maturity}-Year Bond)', fontsize=15)
    ax.set_xlabel('Reinvestment Rate (%)', fontsize=12)
    ax.set_ylabel('Realized Compound Return (%)', fontsize=12)
    ax.set_xlim(0, 15)
    ax.set_ylim(min(realized_returns_curve)*100 - 1, max(realized_returns_curve)*100 + 1)
    ax.legend()
    ax.grid(True, linestyle=':', alpha=0.7)

    plt.show()

# --- 3. Interactive Widgets Setup ---

style = {'description_width': 'initial'}
# --- FIX: Set continuous_update=True for all sliders to make them fully interactive ---
coupon_widget = widgets.FloatSlider(value=10.0, min=2, max=15, step=0.5, description='Coupon Rate (%):', style=style, continuous_update=True)
maturity_widget = widgets.IntSlider(value=2, min=2, max=30, step=1, description='Maturity (Years):', style=style, continuous_update=True)
purchase_ytm_widget = widgets.FloatSlider(value=10.0, min=2, max=15, step=0.5, description='Purchase YTM (%):', style=style, continuous_update=True)
reinvest_rate_widget = widgets.FloatSlider(value=10.0, min=0, max=15, step=0.1, description='Reinvestment Rate (%):', style=style, continuous_update=True)

# Capture each update in this demonstration's own output widget.
reinvestment_output = widgets.interactive_output(
    generate_output,
    {'coupon': coupon_widget, 'maturity': maturity_widget, 'ytm': purchase_ytm_widget, 'current_reinvest_rate': reinvest_rate_widget}
)

reinvestment_controls = widgets.VBox([
    widgets.HTML("<h3>1. Set Bond & Purchase Parameters:</h3>"),
    coupon_widget,
    maturity_widget,
    purchase_ytm_widget,
    widgets.HTML("<hr><h3>2. Explore with Reinvestment Rate Slider:</h3>"),
    reinvest_rate_widget
])

display(reinvestment_controls, reinvestment_output)
# Out:
# ...
# Output()

# %% [markdown]
# ### The Term Structure of Interest Rates
#
# <center>
# <img src = "../images/slide_2/pic_5.png">
# </center>
#
# *   The pure yield curve refers to the curve for stripped, or zero-coupon, Treasuries.
# *   The on-the-run yield curve refers to the plot of yield as a function of maturity for recently issued coupon bonds selling at or near par value.
#
# ---

# %% [markdown]
# ### The Term Structure of Interest Rates
#
# *   If yields on different-maturity bonds are not all equal, how should we value coupon bonds that make payments at many different times?
#
# | Maturity (years) | Yield to Maturity (%) | Price                     |
# | :---------------: | :--------------------: | :------------------------ |
# | 1                | 5                    | $952.38 = \$1,000/1.05$   |
# | 2                | 6                     | $890.00 = \$1,000/1.06^2$ |
# | 3                | 7                     | $816.30 = \$1,000/1.07^3$ |
# | 4                | 8                     | $735.03 = \$1,000/1.08^4$ |
#
# *   Omega considers a four-year bond with a \$1,000 par value and a 6% annual coupon, paid once a year. Using the zero-coupon yields above, what is its price?
#
# $$ P_B = 60\left(\frac{952.38+890.00+816.30}{1,000}\right) + 1,060\left(\frac{735.03}{1,000}\right) $$
# $$ P_B = \frac{60}{1.05} + \frac{60}{1.06^2} + \frac{60}{1.07^3} + \frac{1,060}{1.08^4} = \$938.65 $$
#
# ---

# %% [markdown]
# ### The Term Structure of Interest Rates
#
# *   Why is the yield on the 2-year zero coupon bond is greater than that on the 1-year zero?
#
# | Maturity (years) | Yield to Maturity (%) | Price                     |
# | :---------------: | :--------------------: | :------------------------ |
# | 1                | 5                   | $952.38 = \$1,000/1.05$   |
# | 2                | 6                     | $890.00 = \$1,000/1.06^2$ |
# | 3                | 7                     | $816.30 = \$1,000/1.07^3$ |
# | 4                | 8                     | $735.03 = \$1,000/1.08^4$ |
#
# $890 \cdot (1+6\%)^2 = 890 \cdot (1 + 5\%)(1 + r_{1,2}) \quad \Rightarrow \quad r_{1,2} = 7.01\%$
#
# $(1 + 7\%)^3 = (1 + 6\%)^2(1 + r_{2,3}) \qquad \Rightarrow \qquad r_{2,3} = 9.03\%$
#
# $(1 + 8\%)^4 = (1 + 7\%)^3(1 + r_{3,4}) \qquad \Rightarrow \qquad r_{3,4} = 11.06\%$
#
# ---

# %% [markdown]
# ### The Term Structure of Interest Rates
#
# Today's spot rates imply the following one-year forward rates:
#
# $$ f_n = \frac{(1+y_n)^n}{(1+y_{n-1})^{n-1}} - 1, \qquad n \geq 2 $$
#
# | Year $n$ | Spot rate $y_n$ | One-year forward rate $f_n$ |
# | :---: | :---: | :---: |
# | 1 | 5.00% | 5.00% |
# | 2 | 6.00% | 7.01% |
# | 3 | 7.00% | 9.03% |
# | 4 | 8.00% | 11.06% |
#
# *   $f_1 = y_1$ is today's one-year spot rate. Later forward rates are implied today; the actual future short rates are unknown.
#
# ---

# %% [markdown]
# ### The Term Structure of Interest Rates
#
# #### Spot rate
# *   The yield to maturity on zero-coupon bonds.
# *   The rate that prevails today for a time period corresponding to the zero's maturity.
#
#
# #### Short rate
# *   The one-period interest rate that prevails at a particular date. Future short rates are uncertain today.
#
#
#
# #### Forward rate
# *   The one-year rate implied by today's spot rates that makes an $n$-year zero-coupon investment equivalent to an $(n - 1)$-year zero-coupon investment rolled over for one year at that rate.
# *   It equals the expected future short rate under the expectations hypothesis. A risk premium can make the two differ.
#     *   If short-term investors dominate, the forward rate tends to exceed the expected future short rate to compensate for long-term bond price risk.
#     *   If long-term investors dominate, the forward rate can be below the expected future short rate because rolling over short-term bonds involves reinvestment risk.
#
#
# ---

# %% [markdown]
# ### The Term Structure of Interest Rates
# #### Liquidity
# * Liquidity refers to the ability to sell an asset easily at a predictable price.
# * Long-term bonds have greater price risk, considered less liquid, must offer a premium.
# * Liquidity Premium
#     * The liquidity premium compensates short-term investors for the uncertainty about the price at which they will be able to sell their long-term bonds at the end of the year.
#
# #### The Expectations Hypothesis
# *   The forward rate equals the market consensus expectation of the future short interest rate,
# *   $f_n = E(r_n)$, and liquidity premiums are zero.
# *   Suggests that the yields on long-term bonds depend only on expectations of future short rates.
#     *   The forward rates derived from the yield curve can be used to infer market expectations of future short rates.\
#
# #### Liquidity Preference Theory
# *   Short-term investors will be unwilling to hold long-term bonds unless the forward rate exceeds the expected short interest rate.
# *   Long-term investors will be unwilling to hold short bonds unless the expected short interest rate exceeds the forward rate.
# *   The liquidity preference theory of the term structure argues that short-term investors dominate the market so that the forward rate will generally exceed the expected short rate.
#
# $$ f_n = E(r_n) + \text{Liquidity Premium} $$
#
# ---

# %% [markdown]
# ### The Term Structure of Interest Rates
#
# <center>
# <img src="https://github.com/HoTruongAnBBA2024/Investments_WS2026/blob/main/images/slide_2/pic_8.png?raw=1" width="900">
# </center>
#
# ---

# %% [markdown]
# ![Screenshot 2026-09-25 140050.png](data:image/png;base64,...)

# %% [markdown]
# ### Question 2.1
#
# Kappa observes a 1-year zero-coupon yield of 4% and a 2-year zero-coupon yield of 5%, both with annual compounding.
#
# -   What is the implied 1-year forward rate for year 2?
#
# -   Under the Expectations Hypothesis, what does it imply about the expected short rate?
#
# -   Under Liquidity Preference Theory, could the expected short rate instead remain at 4%? Explain.
#
# ---

# %% [markdown]
# ### Question 2.2
#
# An investor states, "I just bought a 15-year, 7% coupon bond with a 5% Yield to Maturity. I have locked in a 5% annual return for the next 15 years."
#
# Assume annual coupon payments and annual compounding, with all promised payments made and the bond held to maturity.
#
# -   Explain the critical assumption this investor is making about the future.
#
# -   Under what specific scenario involving future interest rates will their actual realized return be less than the promised 5% YTM?
#
# -   If market interest rates rise immediately to 6%, what happens to the bond's price and, if coupons are reinvested at 6% until maturity, to the investor's realized annual return?
#
# ---

# %% [markdown]
# ## 📑 BÀI GIẢI VÀ GHI CHÚ BẢN CHẤT TÀI CHÍNH (BÀI 2.2)## 📊 Thông số đề bài (Inputs):
#
# * Mệnh giá (Face Value - $FV$) = $1,000
#
# * Kỳ hạn (Maturity - $N$) = 15 năm
# * Lãi suất Coupon = 7%/năm $\rightarrow$ Tiền lãi nhận hàng năm ($C$) = $70
# * Lợi suất khi đáo hạn ban đầu (YTM) = 5%/năm
#
# ------------------------------
# ## 🛑 BƯỚC 0: TÍNH TOÁN BAN ĐẦU (CHUYỆN CỦA HIỆN TẠI)
# Trước khi vào câu hỏi, ta phải tính số tiền thực tế cần bỏ ra mua trái phiếu hôm nay (Present Value - $PV$).
#
# * Công thức toán học:
# $$PV = C \times \left[ \frac{1 - (1 + \text{YTM})^{-N}}{\text{YTM}} \right] + \frac{FV}{(1 + \text{YTM})^N}$$
# * Thay số:
# $$PV = 70 \times \left[ \frac{1 - (1.05)^{-15}}{0.05} \right] + \frac{1000}{(1.05)^{15}} \approx \mathbf{\$1,207.59}$$
#
# 💡 Ghi chú Bản chất (Note):
#
# * Thắc mắc: Tại sao giá mua lại là $1,207.59 trong khi mệnh giá chỉ có $1,000?
#
# * Giải đáp: Vì lãi suất Coupon (7%) lớn hơn lãi suất thị trường/YTM (5%), đây là một Premium Bond (Trái phiếu bán cao hơn mệnh giá). Bạn phải chi nhiều tiền hơn để mua được một tài sản trả lãi hời hơn thị trường.
#
# * Thắc mắc 2: Công thức tính giá $1,207.59 này có liên quan gì đến việc mang tiền lãi đi tái đầu tư không?
#
# * Giải đáp: Không! Công thức định giá này chỉ đơn thuần tính toán số tiền cần bỏ ra ở hiện tại dựa trên kỹ thuật chiết khấu (discounting). Nó không chứa bất kỳ phép toán nào về việc tái đầu tư trong tương lai cả.
#
# ------------------------------
# ## ❓ CÂU 1: GIẢ ĐỊNH QUAN TRỌNG NHẤT CỦA NHÀ ĐẦU TƯ (CRITICAL ASSUMPTION)
# Nhà đầu tư tuyên bố: "Tôi đã khóa chặt (locked in) mức lợi nhuận 5% hàng năm cho 15 năm tới". Giả định nào đứng sau lời tuyên bố này?
#
# * Lời giải: Giả định quan trọng nhất là Tất cả các khoản tiền lãi Coupon ($70) nhận được hàng năm phải được đem đi tái đầu tư ngay lập tức với mức lãi suất ổn định bằng đúng YTM (5%) liên tục trong suốt 15 năm.
#
# 💡 Ghi chú Bản chất (Note):
#
# * Thắc mắc: Tại sao lại xuất hiện giả định này khi công thức tính giá ở Bước 0 không hề nhắc tới?
# * Giải đáp: Con số YTM = 5% chỉ là một "lời hứa hẹn lý thuyết". Để tổng tài sản của nhà đầu tư tăng trưởng thực tế (Realized Return) đạt đúng tỷ lệ 5%/năm như YTM, họ không thể cất tiền lãi $70 vào tủ kính, mà buộc phải mang số tiền đó ra thị trường bắt nó đẻ thêm lãi (lãi kép) với tốc độ đúng 5%/năm.
#
# ------------------------------
# ## ❓ CÂU 2: KỊCH BẢN KHIẾN LỢI NHUẬN THỰC TẾ THẤP HƠN 5% (SCENARIO FOR LOWER RETURN)
# Kịch bản nào ngoài nền kinh tế sẽ khiến lợi nhuận thực tế hàng năm (Realized Return) của nhà đầu tư tụt xuống dưới 5%?
#
# * Lời giải: Kịch bản là Lãi suất thị trường trong tương lai sụt giảm xuống dưới mức 5% (ví dụ còn 3%).
#
# 💡 Ghi chú Bản chất (Note):
#
# * Thắc mắc: Tại sao lãi suất thị trường giảm lại làm nhà đầu tư bị "hớ"?
# * Giải đáp: Khi lãi suất thị trường giảm, nhà đầu tư vẫn nhận đều đặn $70 từ doanh nghiệp. Nhưng khi mang $70 này đi gửi ngân hàng hay đầu tư tiếp, họ chỉ được hưởng mức lãi suất thấp hơn (ví dụ 3%). Tiền đẻ ra lãi ít hơn kỳ vọng ban đầu, dẫn đến tổng tài sản thu về ở năm thứ 15 bị hụt đi $\rightarrow$ Lợi nhuận thực tế (Realized Return) bị kéo tụt dưới 5%. Đây gọi là Rủi ro tái đầu tư (Reinvestment Risk).
# * Thắc mắc đặc biệt: Nếu tôi lười, không thèm tái đầu tư (lãi suất tái đầu tư = 0%) thì sao?
# * Giải đáp: Tổng tiền lãi sau 15 năm chỉ là $70 \times 15 = \$1,050$. Cộng gốc $1,000 = \$2,050$. Áp dụng công thức CAGR: $\text{Realized Return} = (2050 / 1207.59)^{(1/15)} - 1 \approx \mathbf{3.58\%}$. (Tụt giảm nghiêm trọng so với YTM 5%).
#
# ------------------------------
# ## ❓ CÂU 3: ĐIỀU GÌ XẢY RA NẾU LÃI SUẤT TĂNG NGAY LẬP TỨC LÊN 6%?
# Nếu lãi suất thị trường nhảy vọt lên 6%, giá trái phiếu và lợi nhuận thực tế của nhà đầu tư biến động thế nào? (Biết nhà đầu tư giữ đến khi đáo hạn).
#
# * Lời giải:
# 1. Giá trái phiếu (Bond Price): Sẽ giảm ngay lập tức trên thị trường.
#    2. Lợi nhuận thực tế (Realized Return): Sẽ lớn hơn 5% khi đáo hạn.
#
# 💡 Ghi chú Bản chất (Note) - Đây là phần hay nhất:
#
# * Thắc mắc: Tại sao giá trái phiếu giảm mà lợi nhuận thực tế cuối cùng lại tăng lên (> 5%)? Chẳng phải hai cái này mâu thuẫn sao?
# * Giải đáp: Không mâu thuẫn, vì có 2 lực tác động ngược chiều nhau:
# * Lực 1 (Tác động lên Giá): Lãi suất thị trường tăng lên 6% làm trái phiếu cũ (YTM 5%) bị mất giá trên sàn giao dịch.
#    * Lực 2 (Tác động lên Tái đầu tư): Vì đề bài nhấn mạnh nhà đầu tư "giữ đến khi đáo hạn" (held to maturity), nghĩa là họ không bán trái phiếu ra thị trường $\rightarrow$ Khoản lỗ về giá bị vô hiệu hóa hoàn toàn. Ngược lại, họ được hưởng lợi lớn: Kể từ năm sau, mỗi khi nhận $70 tiền lãi, họ mang đi tái đầu tư với mức lãi suất mới cao hơn là 6% (thay vì 5%). Tiền đẻ ra lãi nhiều hơn, tổng tài sản cuối cùng ở năm 15 lớn hơn, giúp Realized Return vượt mức 5% (cụ thể tính ra là 5.33%).
#
# ------------------------------
# ## 📐 FILE CÔNG THỨC TOÁN HỌC TỔNG QUÁT (DÀNH CHO GOOGLE COLAB)
# Nếu bạn viết code Python trong Colab, hãy lưu ý cấu trúc toán học của Bước 3 (Chuyện của Tương lai) để chứng minh Realized Return:
#
#    1. Tổng tài sản tại Năm 15 (Future Value - FV):
#    $$FV_{\text{Năm 15}} = \underbrace{C \times \frac{(1 + r_{\text{tái đầu tư}})^N - 1}{r_{\text{tái đầu tư}}}}_{\text{Tích lũy chuỗi tiền lãi Coupon}} + \underbrace{1,000}_{\text{Gốc Face Value giữ nguyên}}$$
#    (Ghi chú: $1,000 đứng sẵn ở năm 15 nên KHÔNG chiết khấu ngược về).
#    2. Tính Realized Return:
#    $$\text{Realized Return} = \left( \frac{FV_{\text{Năm 15}}}{PV_{\text{Ban đầu}}} \right)^{\frac{1}{15}} - 1$$
#
# ------------------------------

# %% [markdown]
# ### Question 2.3
#
# A 10-year bond with a face value of \$1,000 has a 6% coupon rate with semiannual payments.
#
# If the market yield on a comparable noncallable bond is 4%, what is this bond's value if it is not called?
#
# If the bond can be called immediately for \$1,040, would you expect the issuer to call it today? Why or why not? Ignore accrued interest and call costs.
#
# ---

# %% [markdown]
# ### Question 2.4
#
# A bond with a 6% coupon rate, paid semi-annually, and a face value of $\$1,000$ has a quoted flat price of $\$1,035$. You purchase this bond 75 days after the last coupon payment. Assuming there are 180 days in the current semi-annual coupon period, calculate:
#
# - The accrued interest.
#
# - The full invoice price you will actually pay for the bond.
#
# ---

# %% [markdown]
# ### Question 2.5
#
# You are analyzing a 20-year, 7% coupon bond with a face value of $\$1,000$. The bond pays semi-annual coupons and is currently selling for $\$1,090$. The bond can be called in 6 years at a call price of $\$1,040$.
#
# - Calculate the bond's Yield to Maturity, or YTM.
#
# - Calculate the bond's Yield to Call, or YTC.
#
# - Which of these is the more relevant measure of expected return for an investor purchasing the bond today? Justify your answer.
#
# ---

# %% [markdown]
# ### What is next?
#
# * Fixed-Income Securities II
# * Managing Bond Portfolios
# * Readings: Ch. 16
#
# #### Suggested Problems
# *   Ch. 14: 6, 10, 14, 21, 23, 29
# *   Ch 14 – CFA Problems: 2, 4
# *   Ch. 15: 7, 10, 13, 17
# *   Ch 15 – CFA Problems: 4, 9
#
# ---
